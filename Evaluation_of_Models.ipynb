# %% [markdown]
# --- Evaluating All Models (Base + Ensemble) ---
#
# Training and evaluating: Logistic Regression
# Accuracy for Logistic Regression: 0.9358
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96        77
#            1       0.96      0.81      0.88        32
#
#     accuracy                           0.94       109
#    macro avg       0.94      0.90      0.92       109
# weighted avg       0.94      0.94      0.93       109
#
# --------------------------------------------------
# Training and evaluating: Support Vector Machine (Linear Kernel)
# Accuracy for Support Vector Machine (Linear Kernel): 0.9450
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96        77
#            1       0.96      0.84      0.90        32
#
#     accuracy                           0.94       109
#    macro avg       0.95      0.92      0.93       109
# weighted avg       0.95      0.94      0.94       109
#
# --------------------------------------------------
# Training and evaluating: Support Vector Machine (RBF Kernel)
# Accuracy for Support Vector Machine (RBF Kernel): 0.9541
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        77
#            1       1.00      0.84      0.92        32
#
#     accuracy                           0.95       109
#    macro avg       0.97      0.92      0.94       109
# weighted avg       0.96      0.95      0.95       109
#
# --------------------------------------------------
# Training and evaluating: Random Forest Classifier
# Accuracy for Random Forest Classifier: 0.9266
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95        77
#            1       0.96      0.78      0.86        32
#
#     accuracy                           0.93       109
#    macro avg       0.94      0.88      0.91       109
# weighted avg       0.93      0.93      0.92       109
#
# --------------------------------------------------
# Training and evaluating: Gradient Boosting Classifier
# Accuracy for Gradient Boosting Classifier: 0.9725
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        77
#            1       0.97      0.94      0.95        32
#
#     accuracy                           0.97       109
#    macro avg       0.97      0.96      0.97       109
# weighted avg       0.97      0.97      0.97       109
#
# --------------------------------------------------
# Training and evaluating: K-Nearest Neighbors
# Accuracy for K-Nearest Neighbors: 0.9358
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        77
#            1       1.00      0.78      0.88        32
#
#     accuracy                           0.94       109
#    macro avg       0.96      0.89      0.92       109
# weighted avg       0.94      0.94      0.93       109
#
# --------------------------------------------------
# Training and evaluating: Decision Tree Classifier
# Accuracy for Decision Tree Classifier: 0.8991
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        77
#            1       0.84      0.81      0.83        32
#
#     accuracy                           0.90       109
#    macro avg       0.88      0.87      0.88       109
# weighted avg       0.90      0.90      0.90       109
#
# --------------------------------------------------
# Training and evaluating: Random Forest
# Accuracy for Random Forest: 0.9266
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95        77
#            1       0.96      0.78      0.86        32
#
#     accuracy                           0.93       109
#    macro avg       0.94      0.88      0.91       109
# weighted avg       0.93      0.93      0.92       109
#
# --------------------------------------------------
# Training and evaluating: Gradient Boosting
# Accuracy for Gradient Boosting: 0.9725
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        77
#            1       0.97      0.94      0.95        32
#
#     accuracy                           0.97       109
#    macro avg       0.97      0.96      0.97       109
# weighted avg       0.97      0.97      0.97       109
#
# --------------------------------------------------
# Training and evaluating: AdaBoost
# Accuracy for AdaBoost: 0.9083
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93        77
#            1       0.82      0.88      0.85        32
#
#     accuracy                           0.91       109
#    macro avg       0.89      0.90      0.89       109
# weighted avg       0.91      0.91      0.91       109
#
# --------------------------------------------------
# Training and evaluating: Bagging (Decision Tree)
# Accuracy for Bagging (Decision Tree): 0.9541
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        77
#            1       0.94      0.91      0.92        32
#
#     accuracy                           0.95       109
#    macro avg       0.95      0.94      0.94       109
# weighted avg       0.95      0.95      0.95       109
#
# --------------------------------------------------
# Training and evaluating: Voting Classifier (Hard)
# Accuracy for Voting Classifier (Hard): 0.9541
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97        77
#            1       0.97      0.88      0.92        32
#
#     accuracy                           0.95       109
#    macro avg       0.96      0.93      0.94       109
# weighted avg       0.95      0.95      0.95       109
#
# --------------------------------------------------
# Training and evaluating: Voting Classifier (Soft)
# Accuracy for Voting Classifier (Soft): 0.9450
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96        77
#            1       0.96      0.84      0.90        32
#
#     accuracy                           0.94       109
#    macro avg       0.95      0.92      0.93       109
# weighted avg       0.95      0.94      0.94       109

# %% [markdown]
# The best performing model is: Gradient Boosting Classifier with accuracy: 0.9725
