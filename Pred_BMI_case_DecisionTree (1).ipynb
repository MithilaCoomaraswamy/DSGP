# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/Exercise dataset.csv')

# %%
data.head()
# Out:
#        Weight    Height        BMI  Age      BMIcase  BMI_No  \
# 0   92.085190  1.760250  29.719488   59  over weight       5
# 1   61.089124  1.595499  23.997776   25       normal       4
# 2   82.454037  1.816538  24.987499   50       normal       4
# 3  101.713306  1.790696  31.720047   62        obese       6
# 4   62.347337  1.543259  26.178219   35  over weight       5
#
#                                         Gym Exercise  \
# 0  Treadmill Walking with Intervals; Moderate Wei...
# 1  Moderate Weight Training (Full Body Workout); ...
# 2  Moderate Weight Training (Full Body Workout); ...
# 3  Low-Impact Cardio (Elliptical, Cycling); Seate...
# 4  Treadmill Walking with Intervals; Moderate Wei...
#
#                                        Home Exercise
# 0  Modified Burpees; Step-Ups on a Sturdy Chair o...
# 1  Jump Rope; High Knees; Planks; Squats and Lung...
# 2  Jump Rope; High Knees; Planks; Squats and Lung...
# 3  Chair Squats; Modified Plank; Seated Leg Lifts...
# 4  Modified Burpees; Step-Ups on a Sturdy Chair o...

# %%
data.shape
# Out:
# (2492, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2492 entries, 0 to 2491
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Weight         2492 non-null   float64
#  1   Height         2492 non-null   float64
#  2   BMI            2492 non-null   float64
#  3   Age            2492 non-null   int64
#  4   BMIcase        2492 non-null   object
#  5   BMI_No         2492 non-null   int64
#  6   Gym Exercise   2492 non-null   object
#  7   Home Exercise  2492 non-null   object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 155.9+ KB

# %%
x = data.iloc[:,0:4]
x.head()
# Out:
#        Weight    Height        BMI  Age
# 0   92.085190  1.760250  29.719488   59
# 1   61.089124  1.595499  23.997776   25
# 2   82.454037  1.816538  24.987499   50
# 3  101.713306  1.790696  31.720047   62
# 4   62.347337  1.543259  26.178219   35

# %%
y = data.iloc[:,4:5]
y.head()
# Out:
#        BMIcase
# 0  over weight
# 1       normal
# 2       normal
# 3        obese
# 4  over weight

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape
# Out:
# (1744, 4)

# %%
x_test.shape
# Out:
# (748, 4)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(x_test)
pred
# Out:
# array(['obese', 'over weight', 'severe obese', 'moderate thinness',
#        'obese', 'normal', 'over weight', 'moderate thinness',
#        'severe obese', 'obese', 'normal', 'severe obese', 'severe obese',
#        'severe obese', 'severe obese', 'obese', 'over weight',
#        'severe obese', 'over weight', 'normal', 'severe obese', 'obese',
#        'normal', 'over weight', 'severe obese', 'obese', 'severe obese',
#        'obese', 'obese', 'severe obese', 'normal', 'over weight',
#        'over weight', 'over weight', 'severe obese', 'over weight',
#        'severe obese', 'over weight', 'normal', 'obese', 'over weight',
#        'normal', 'normal', 'obese', 'severe obese', 'over weight',
#        'over weight', 'over weight', 'normal', 'obese', 'severe obese',
#        'over weight', 'over weight', 'obese', 'severe obese',
#        'over weight', 'over weight', 'obese', 'normal', 'over weight',
#        'normal', 'obese', 'obese', 'normal', 'over weight', 'over weight',
#        'severe obese', 'obese', 'severe obese', 'severe obese',
#        'over weight', 'normal', 'severe obese', 'normal', 'normal',
#        'severe obese', 'normal', 'severe obese', 'severe obese',
#        'over weight', 'over weight', 'normal', 'severe obese', 'normal',
#        'over weight', 'severe obese', 'over weight', 'severe obese',
#        'severe obese', 'severe obese', 'over weight', 'normal', 'normal',
#        'normal', 'obese', 'normal', 'obese', 'over weight',
#        'severe obese', 'over weight', 'obese', 'moderate thinness',
#        'obese', 'over weight', 'over weight', 'over weight',
#        'severe obese', 'normal', 'over weight', 'normal', 'obese',
#        'severe obese', 'severe obese', 'over weight', 'severe obese',
#        'severe obese', 'obese', 'over weight', 'severe obese',
#        'over weight', 'obese', 'severe obese', 'severe obese',
#        'over weight', 'severe obese', 'normal', 'over weight',
#        'over weight', 'over weight', 'obese', 'sever thinness',
#        'severe obese', 'severe obese', 'normal', 'over weight', 'obese',
#        'severe obese', 'obese', 'severe obese', 'normal', 'normal',
#        'over weight', 'normal', 'over weight', 'obese', 'normal',
#        'severe obese', 'normal', 'severe obese', 'obese', 'severe obese',
#        'obese', 'normal', 'severe obese', 'over weight', 'severe obese',
#        'over weight', 'severe obese', 'obese', 'severe obese', 'obese',
#        'severe obese', 'over weight', 'severe obese', 'normal',
#        'over weight', 'obese', 'normal', 'normal', 'obese', 'normal',
#        'severe obese', 'normal', 'over weight', 'over weight', 'normal',
#        'obese', 'severe obese', 'severe obese', 'over weight', 'normal',
#        'over weight', 'severe obese', 'normal', 'severe obese', 'normal',
#        'severe obese', 'severe obese', 'over weight', 'over weight',
#        'obese', 'over weight', 'sever thinness', 'moderate thinness',
#        'severe obese', 'normal', 'normal', 'obese', 'over weight',
#        'normal', 'severe obese', 'mild thinness', 'severe obese',
#        'over weight', 'severe obese', 'normal', 'normal', 'over weight',
#        'obese', 'over weight', 'over weight', 'obese',
#        'moderate thinness', 'obese', 'obese', 'severe obese',
#        'severe obese', 'severe obese', 'obese', 'over weight',
#        'over weight', 'severe obese', 'obese', 'over weight',
#        'severe obese', 'obese', 'obese', 'severe obese', 'severe obese',
#        'obese', 'obese', 'over weight', 'normal', 'severe obese',
#        'normal', 'severe obese', 'obese', 'normal', 'severe obese',
#        'severe obese', 'normal', 'severe obese', 'severe obese',
#        'severe obese', 'severe obese', 'obese', 'obese', 'over weight',
#        'obese', 'over weight', 'normal', 'over weight', 'severe obese',
#        'obese', 'obese', 'obese', 'mild thinness', 'obese', 'over weight',
#        'over weight', 'normal', 'over weight', 'obese', 'obese',
#        'mild thinness', 'over weight', 'over weight', 'moderate thinness',
#        'moderate thinness', 'obese', 'severe obese', 'severe obese',
#        'normal', 'over weight', 'normal', 'obese', 'normal', 'obese',
#        'normal', 'obese', 'normal', 'severe obese', 'normal', 'normal',
#        'severe obese', 'severe obese', 'over weight', 'normal',
#        'over weight', 'obese', 'severe obese', 'severe obese',
#        'over weight', 'obese', 'over weight', 'normal', 'obese', 'normal',
#        'severe obese', 'normal', 'normal', 'severe obese', 'severe obese',
#        'severe obese', 'normal', 'obese', 'obese', 'over weight',
#        'normal', 'obese', 'over weight', 'normal', 'over weight',
#        'severe obese', 'obese', 'severe obese', 'severe obese',
#        'over weight', 'obese', 'severe obese', 'over weight',
#        'over weight', 'normal', 'obese', 'normal', 'obese', 'over weight',
#        'obese', 'normal', 'over weight', 'normal', 'over weight',
#        'over weight', 'normal', 'obese', 'over weight', 'over weight',
#        'normal', 'obese', 'obese', 'over weight', 'over weight',
#        'over weight', 'severe obese', 'severe obese', 'severe obese',
#        'normal', 'obese', 'over weight', 'severe obese', 'obese',
#        'severe obese', 'severe obese', 'normal', 'normal', 'over weight',
#        'normal', 'severe obese', 'severe obese', 'normal', 'normal',
#        'obese', 'normal', 'obese', 'severe obese', 'obese', 'obese',
#        'normal', 'over weight', 'severe obese', 'over weight', 'obese',
#        'severe obese', 'obese', 'severe obese', 'severe obese',
#        'over weight', 'severe obese', 'obese', 'normal', 'obese',
#        'severe obese', 'severe obese', 'severe obese', 'normal',
#        'severe obese', 'normal', 'normal', 'severe obese', 'severe obese',
#        'normal', 'normal', 'over weight', 'obese', 'severe obese',
#        'moderate thinness', 'severe obese', 'over weight', 'obese',
#        'obese', 'severe obese', 'obese', 'normal', 'severe obese',
#        'severe obese', 'over weight', 'obese', 'normal', 'severe obese',
#        'normal', 'normal', 'normal', 'severe obese', 'severe obese',
#        'over weight', 'normal', 'severe obese', 'obese', 'normal',
#        'normal', 'over weight', 'severe obese', 'severe obese',
#        'over weight', 'severe obese', 'over weight', 'obese',
#        'over weight', 'severe obese', 'normal', 'obese', 'severe obese',
#        'severe obese', 'obese', 'severe obese', 'sever thinness',
#        'severe obese', 'severe obese', 'severe obese', 'obese',
#        'severe obese', 'normal', 'obese', 'obese', 'severe obese',
#        'severe obese', 'severe obese', 'over weight', 'over weight',
#        'normal', 'severe obese', 'over weight', 'severe obese', 'normal',
#        'severe obese', 'normal', 'obese', 'over weight', 'normal',
#        'obese', 'obese', 'obese', 'obese', 'severe obese', 'severe obese',
#        'obese', 'obese', 'severe obese', 'over weight', 'normal', 'obese',
#        'obese', 'severe obese', 'over weight', 'severe obese',
#        'over weight', 'over weight', 'normal', 'severe obese', 'normal',
#        'severe obese', 'over weight', 'obese', 'severe obese', 'obese',
#        'over weight', 'normal', 'over weight', 'normal', 'severe obese',
#        'over weight', 'normal', 'obese', 'normal', 'severe obese',
#        'obese', 'obese', 'severe obese', 'severe obese', 'severe obese',
#        'severe obese', 'severe obese', 'severe obese', 'severe obese',
#        'normal', 'over weight', 'normal', 'obese', 'over weight',
#        'over weight', 'normal', 'obese', 'obese', 'severe obese', 'obese',
#        'obese', 'severe obese', 'severe obese', 'normal', 'mild thinness',
#        'over weight', 'severe obese', 'severe obese', 'over weight',
#        'obese', 'normal', 'obese', 'normal', 'obese', 'severe obese',
#        'severe obese', 'severe obese', 'normal', 'severe obese',
#        'severe obese', 'severe obese', 'mild thinness', 'obese',
#        'severe obese', 'severe obese', 'normal', 'over weight',
#        'over weight', 'obese', 'obese', 'obese', 'severe obese',
#        'severe obese', 'sever thinness', 'obese', 'severe obese',
#        'severe obese', 'moderate thinness', 'obese', 'obese',
#        'over weight', 'over weight', 'normal', 'severe obese',
#        'over weight', 'severe obese', 'obese', 'normal', 'obese',
#        'over weight', 'severe obese', 'obese', 'severe obese', 'obese',
#        'over weight', 'normal', 'severe obese', 'obese', 'severe obese',
#        'severe obese', 'obese', 'normal', 'severe obese', 'severe obese',
#        'over weight', 'obese', 'over weight', 'obese', 'normal', 'obese',
#        'normal', 'severe obese', 'severe obese', 'over weight', 'obese',
#        'severe obese', 'over weight', 'mild thinness', 'over weight',
#        'severe obese', 'normal', 'obese', 'over weight', 'normal',
#        'over weight', 'mild thinness', 'obese', 'severe obese', 'normal',
#        'severe obese', 'normal', 'obese', 'over weight', 'over weight',
#        'normal', 'severe obese', 'normal', 'over weight', 'normal',
#        'mild thinness', 'severe obese', 'moderate thinness',
#        'over weight', 'severe obese', 'severe obese', 'normal',
#        'severe obese', 'over weight', 'obese', 'severe obese', 'obese',
#        'obese', 'obese', 'obese', 'severe obese', 'normal', 'obese',
#        'obese', 'normal', 'over weight', 'obese', 'over weight',
#        'moderate thinness', 'normal', 'normal', 'severe obese', 'obese',
#        'normal', 'normal', 'normal', 'normal', 'over weight',
#        'severe obese', 'severe obese', 'severe obese', 'severe obese',
#        'normal', 'normal', 'severe obese', 'moderate thinness',
#        'severe obese', 'normal', 'severe obese', 'severe obese', 'obese',
#        'obese', 'obese', 'obese', 'obese', 'normal', 'obese',
#        'over weight', 'obese', 'obese', 'over weight', 'normal',
#        'severe obese', 'severe obese', 'over weight', 'over weight',
#        'over weight', 'over weight', 'severe obese', 'obese', 'obese',
#        'normal', 'over weight', 'severe obese', 'normal', 'normal',
#        'mild thinness', 'over weight', 'obese', 'severe obese', 'normal',
#        'over weight', 'severe obese', 'over weight', 'obese',
#        'severe obese', 'over weight', 'severe obese', 'obese',
#        'over weight', 'over weight', 'normal', 'over weight',
#        'over weight', 'over weight', 'severe obese', 'over weight',
#        'over weight', 'severe obese', 'normal', 'moderate thinness',
#        'over weight', 'sever thinness', 'normal', 'severe obese',
#        'severe obese', 'normal', 'severe obese', 'severe obese', 'obese',
#        'obese', 'severe obese', 'severe obese', 'severe obese', 'obese',
#        'normal', 'over weight', 'over weight', 'severe obese', 'normal',
#        'obese', 'normal', 'over weight', 'severe obese', 'obese',
#        'over weight', 'normal', 'obese', 'normal', 'normal',
#        'over weight', 'over weight', 'severe obese', 'over weight',
#        'severe obese', 'over weight', 'severe obese', 'over weight',
#        'severe obese'], dtype=object)

# %%
y_test
# Out:
#                 BMIcase
# 724        severe obese
# 41          over weight
# 1235        over weight
# 1040  moderate thinness
# 772        severe obese
# ...                 ...
# 2133        over weight
# 1056       severe obese
# 333        severe obese
# 415         over weight
# 2293       severe obese
#
# [748 rows x 1 columns]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.7366310160427807

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[  9,   0,   0,   0,   0,   0,   0],
#        [  0,  13,   0,   0,   0,   0,   0],
#        [  0,   0, 153,   0,   0,   0,   5],
#        [  0,   0,   0,  93,   0,   0,  55],
#        [  0,   0,   0,   0, 140,   0,  29],
#        [  0,   0,   0,   0,   0,   5,   0],
#        [  0,   0,   4,  73,  31,   0, 138]])
